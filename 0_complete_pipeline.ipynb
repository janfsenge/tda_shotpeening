# %% [markdown]
# # Run all different jupyter notebboks and python scripts

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.config import simulation_parameters

# %%
simulation_parameters
# Out:
# {'simulation_processed': 'nom_filt',
#  'bigger_grid': True,
#  'interpolation_size_preprocess': 1023,
#  'interpolation_size_postprocess': 0,
#  'cut_off_wavelength': 0.8,
#  'calculation_method': 'nom_filt',
#  'train_size': 0.5,
#  'n_cross_val': 10,
#  'random_state_cv': 42,
#  'random_state_classifier': 42}

# %%
# %run 1_read_files.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Are all x_grids the same? False
# Are all y_grids the same? False
# Do we have regular grids: True
# Are all x_grids evenely spaced? False
# Are all y_grids evenely spaced? False
#              coverage_normalized
#                              min      mean       max
# coverage_old
# 16                      0.304893  0.367548  0.379706
# 33                      0.633272  0.689460  0.716305
# 50                      0.841637  0.882743  0.906970
# 66                      0.940166  0.964838  0.978253
# 83                      0.990172  0.994277  0.998371
# 100                     0.998712  0.999907  1.000000
# No overlap!
# bins: [0.5064891161580956, 0.7789709845114944, 0.9235676480482361, 0.9842125386223234, 0.9985416477689946]
# mean coverages: [ 37  69  88  96  99 100]

# %%
# %run 2_compute_roughness.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Processing of the surface is done using: nom_filt
# Remove a least square fitted plane from surface: True
# Use gausian filter: True
# Inteprolation postproces: 0
# Postprocessing took 87.18826007843018 seconds.
# Calculating conventional parameters took 44.605822801589966 seconds.
# Calculating persistence took 141.94190192222595 seconds.
# Calculating persistence parameters took 10.820688009262085 seconds.

# %%
# %run 3_scatter_betti.ipynb
# Out:
# [autoreload of config failed: Traceback (most recent call last):
#   File "/opt/anaconda3/envs/shotpeening/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/opt/anaconda3/envs/shotpeening/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/opt/anaconda3/envs/shotpeening/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/opt/anaconda3/envs/shotpeening/lib/python3.8/importlib/__init__.py", line 168, in reload
#     raise ModuleNotFoundError(f"spec not found for the module {name!r}", name=name)
# ModuleNotFoundError: spec not found for the module 'config'
# ]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Is there a overlap of 0D Entropy values for the last two classes?
#   No overlap!
# ...

# %% [markdown]
# # Classification

# %%
# %cd src/
# Out:
# /Users/janfelixsenge/GitBucket/github_tda_shotpeening/tda_shotpeening/tda_shotpeening/src

# %%
# %run classifier_compute.py
# Out:
# Calculating Classifiers for TDA-representations
# Calculating Classifiers for scalar-classifiers
# 100%|██████████| 15/15 [01:25<00:00,  5.71s/it]
# Calculating Classifiers for scalar-SVM-classifiers
# 100%|██████████| 15/15 [00:30<00:00,  2.02s/it]
# Fine: program ran.
# Dataframe created: tda_representations
# Appended: scalar
# Appended: scalar_svm
# File saved!

# %%
# %cd ..
# Out:
# /Users/janfelixsenge/GitBucket/github_tda_shotpeening/tda_shotpeening/tda_shotpeening

# %%
# %run 4_classification.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# All conventional parameteres as input
# 0 [0.91998299] SVM
# 1 [0.90569558] DT
# 2 [0.90373639] RF
# 3 [0.90573129] MLP
# 4 [0.89557483] KN
# Skewness and interfacial developed area ratio
# 0 [0.94272619] SVM
# 1 [0.89986054] DT
# 2 [0.92231293] RF
# 3 [0.93447789] MLP
# 4 [0.90394558] KN
# Single feature: Skewness
# 0 [0.93056122] SVM
# 1 [0.8732466] DT
# 2 [0.8732466] RF
# 3 [0.85879252] MLP
# 4 [0.88536735] KN
# Single feature: arithmetic mean height
# 0 [0.60482143] SVM
# 1 [0.56017007] DT
# 2 [0.56017007] RF
# 3 [0.61752721] MLP
# 4 [0.56816667] KN
# Selection of 0D persistence-based features
# 0 [0.99587585] SVM
# 1 [0.96534184] DT
# 2 [0.99179422] RF
# 3 [0.98567177] MLP
# 4 [0.9897534] KN
# vectorization:
# 0 [0.9795068] BC
# 1 [0.88757313] LS
# 2 [0.89965306] Si
# 0D Entropy
# 0 [1.] SVM
# 1 [1.] DT
# 2 [1.] RF
# 3 [1.] MLP
# 4 [0.99183673] KN
# $L^2$ norm of the 0D Betti curve
# ...

# %%
# %run 5_clustering.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Conv, number of misslabelled samples: 11
# TDA , number of misslabelled samples: 2
# How many clusters are automatically detected:
# 6 6
# Conv, number of misslabelled samples: 7
# TDA, number of misslabelled samples: 2
